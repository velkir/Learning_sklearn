# %% [markdown]
# # Exercise 31

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split


pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 200)
np.set_printoptions(precision=2, suppress=True, linewidth=100)
raw_data = load_breast_cancer()

data = raw_data['data']
target = raw_data['target']

X_train, y_train, X_test, y_test = train_test_split(data, target, random_state=40, test_size=0.25)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (426, 30)
# (143, 30)
# (426,)
# (143,)

# %% [markdown]
# # Exercise 32

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split


pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 200)
np.set_printoptions(precision=2, suppress=True, linewidth=100)
raw_data = load_breast_cancer()

data = raw_data['data']
target = raw_data['target']

X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=40, test_size=0.25)
ind, target_counts = np.unique(target,return_counts=True)
print(f'target :{target_counts/len(target)}')

ind, y_train_counts = np.unique(y_train,return_counts=True)
print(f'y_train:{y_train_counts/len(y_train)}')

ind, y_test_counts = np.unique(y_test,return_counts=True)
print(f'y_test :{y_test_counts/len(y_test)}')
# Out:
# target :[0.37 0.63]
# y_train:[0.39 0.61]
# y_test :[0.31 0.69]

# %% [markdown]
# # Exercise 33

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split


pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 200)
np.set_printoptions(precision=2, suppress=True, linewidth=100)
raw_data = load_breast_cancer()

data = raw_data['data']
target = raw_data['target']
X_train, X_test, y_train, y_test = train_test_split(data, target,stratify=target, random_state=40, test_size=0.25)
for name, array in zip(['target', 'y_train', 'y_test'], [target, y_train, y_test]):
    print(f'{name.ljust(7)}:{np.unique(array, return_counts=True)[1] / len(array)}')
# Out:
# target :[0.37 0.63]
# y_train:[0.37 0.63]
# y_test :[0.37 0.63]

# %% [markdown]
# # Exercise 34

# %%
import numpy as np
import pandas as pd


df = pd.DataFrame({'years': [1, 2, 3, 4, 5, 6],
                   'salary': [4000, 4250, 4500, 4750, 5000, 5250]})

A = np.vstack([df["years"], np.ones(len(df["years"]))]).T

x = df["years"]
y = df["salary"]

model = np.polyfit(x, y, 1)
print(f'Linear regression: {round(model[1],3):.2f} + {round(model[0],3):.2f}x')
# Out:
# Linear regression: 3750.00 + 250.00x

# %% [markdown]
# # Exercise 35

# %%
import sklearn
from sklearn.linear_model import LinearRegression

df = pd.DataFrame({'years': [1, 2, 3, 4, 5, 6],
                   'salary': [4000, 4250, 4500, 4750, 5000, 5250]})

# X = np.reshape(df["years"], (-1, 1))
# y = np.reshape(df["salary"], (-1, 1))

X = df[["years"]]
y = df[["salary"]]

model = LinearRegression().fit(X, y)

print("Linear regression: {} + {}x".format(model.intercept_[0], model.coef_[0][0]))
# Out:
# Linear regression: 3750.0 + 250.0x

# %% [markdown]
# # Exercise 36

# %%
csv = "utility_file.csv"

df = pd.read_csv(csv)

X = df[["variable"]]
y = df[["target"]]

model = LinearRegression().fit(X, y)
round(model.score(X, y), 4)
# Out:
# 0.5532

# %% [markdown]
# # Exercise 37

# %%
from sklearn.preprocessing import PolynomialFeatures

np.set_printoptions(precision=3)

csv = "task37_utility.csv"
df = pd.read_csv(csv)
X = df[["var1"]]

poly = PolynomialFeatures(2)
poly.fit_transform(X)
# Out:
# array([[ 1.   , -0.542,  0.294],
#        [ 1.   ,  0.529,  0.279],
#        [ 1.   ,  0.625,  0.391],
#        [ 1.   ,  0.194,  0.038],
#        [ 1.   , -0.8  ,  0.64 ],
#        [ 1.   , -0.304,  0.092],
#        [ 1.   ,  1.086,  1.18 ],
#        [ 1.   , -1.16 ,  1.346],
#        [ 1.   ,  1.038,  1.078],
#        [ 1.   , -0.815,  0.665],
#        [ 1.   ,  0.416,  0.173],
#        [ 1.   ,  1.297,  1.683],
#        [ 1.   , -0.433,  0.187],
#        [ 1.   ,  1.059,  1.121],
#        [ 1.   ,  1.139,  1.297],
#        [ 1.   ,  1.   ,  1.   ],
#        [ 1.   ,  0.109,  0.012],
#        [ 1.   , -0.39 ,  0.152],
#        [ 1.   , -0.701,  0.491],
#        [ 1.   ,  0.698,  0.488],
#        [ 1.   ,  0.752,  0.565],
#        [ 1.   ,  0.661,  0.437],
#        [ 1.   , -0.964,  0.93 ],
#        [ 1.   , -0.252,  0.064],
#        [ 1.   ,  0.344,  0.119],
#        [ 1.   ,  0.524,  0.274],
#        [ 1.   , -0.164,  0.027],
#        [ 1.   ,  0.048,  0.002],
# ...

# %% [markdown]
# # Exercise 38

# %%
csv = "task38_utility.csv"
df = pd.read_csv(csv)

poly = PolynomialFeatures(3)
poly.fit_transform(df)
# Out:
# array([[  1.   ,  -0.016,   0.589,   0.   ,  -0.01 ,   0.347,  -0.   ,   0.   ,  -0.006,   0.204],
#        [  1.   ,   0.754,   0.076,   0.569,   0.058,   0.006,   0.429,   0.043,   0.004,   0.   ],
#        [  1.   ,  -1.157,  -1.465,   1.338,   1.695,   2.146,  -1.548,  -1.96 ,  -2.482,  -3.143],
#        [  1.   ,   0.177,  -0.175,   0.031,  -0.031,   0.031,   0.006,  -0.006,   0.005,  -0.005],
#        [  1.   ,  -2.502,   1.536,   6.258,  -3.843,   2.36 , -15.656,   9.615,  -5.905,   3.626],
#        [  1.   ,   0.631,   0.537,   0.398,   0.339,   0.288,   0.251,   0.214,   0.182,   0.155],
#        [  1.   ,   0.239,   0.227,   0.057,   0.054,   0.051,   0.014,   0.013,   0.012,   0.012],
#        [  1.   ,   1.062,   0.598,   1.127,   0.635,   0.358,   1.197,   0.675,   0.38 ,   0.214],
#        [  1.   ,  -0.837,  -0.328,   0.7  ,   0.275,   0.108,  -0.586,  -0.23 ,  -0.09 ,  -0.035],
# ...

# %% [markdown]
# # Exercise 39

# %%
from sklearn.metrics import mean_absolute_error

csv = "task39_utility.csv"

df = pd.read_csv(csv)

y_true = df["y_true"]
y_pred = df["y_pred"]

round(mean_absolute_error(y_true, y_pred), 4)
# Out:
# 6.7918

# %% [markdown]
# # Exercise 40

# %%
from sklearn.metrics import mean_absolute_error

csv = "task40_utility.csv"

df = pd.read_csv(csv)

y_true = df["y_true"]
y_pred = df["y_pred"]

round(mean_absolute_error(y_true, y_pred), 4)
# Out:
# 6.7918

# %% [markdown]
# # Exercise 41

# %%
import math

def sigmoid(x):
  return 1/1+math.e**(-x)

csv = "task41_utility.csv"

df = pd.read_csv(csv)

df["var1_sigmoid"] = sigmoid(df["var1"])
df
# Out:
#        var1  var1_sigmoid
# 0  1.161966      1.312870
# 1  0.251008      1.778016
# 2  0.948663      1.387258
# 3 -0.141041      2.151472
# 4  0.978152      1.376005
# 5  0.496576      1.608611
# 6 -0.006001      2.006019
# 7 -0.350019      2.419095
# 8 -0.693200      3.000106
# 9 -2.422743     12.276749
