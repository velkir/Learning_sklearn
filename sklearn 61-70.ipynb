# %% [markdown]
# 61

# %%
from sklearn.cluster import KMeans
import pandas as pd

data = pd.read_csv("/content/Utility_sklearn.csv")
WCSS = []

for i in range(2, 10):
  kmeans = KMeans(n_clusters=i, n_init=10, random_state=42)
  kmeans.fit(data)
  WCSS.append(round(kmeans.inertia_, 2))

# %% [markdown]
# 62

# %%
from sklearn.cluster import KMeans
import pandas as pd

data = pd.read_csv("/content/Utility_sklearn.csv")
WCSS = []

for i in range(2, 10):
  kmeans = KMeans(n_clusters=i, n_init=10, random_state=42)
  kmeans.fit(data)
  WCSS.append(round(kmeans.inertia_, 2))

for n in range(len(WCSS)-1):
  if WCSS[n]/WCSS[n+1] < 1.5:
    print(n+1)
    break
  # print(WCSS[n]/WCSS[n+1])
# Out:
# 3

# %% [markdown]
# 63

# %%
from sklearn.cluster import AgglomerativeClustering

df = pd.read_csv("/content/Utility_sklearn.csv")
aggl = AgglomerativeClustering(n_clusters=2)
aggl.fit(df)
df["cluster"] = aggl.labels_
df.head(10)
# Out:
#          x1        x2  cluster
# 0 -2.486532  7.025770        1
# 1 -3.522549  8.578303        1
# 2 -2.982040  7.998514        1
# 3 -2.135276  6.255888        1
# 4  2.762504  4.210918        0
# 5 -3.541472  8.489106        1
# 6  1.240259  0.781640        0
# 7  0.053390  8.966770        1
# 8 -0.827918  6.742253        1
# 9  3.291716  1.296751        0

# %% [markdown]
# 64

# %%
from sklearn.cluster import AgglomerativeClustering

df = pd.read_csv("/content/Utility_sklearn.csv")
aggl = AgglomerativeClustering(n_clusters=2, metric="manhattan", linkage="complete")
aggl.fit(df)
df["cluster"] = aggl.labels_
df.head(10)
# Out:
#          x1        x2  cluster
# 0 -2.486532  7.025770        0
# 1 -3.522549  8.578303        0
# 2 -2.982040  7.998514        0
# 3 -2.135276  6.255888        0
# 4  2.762504  4.210918        0
# 5 -3.541472  8.489106        0
# 6  1.240259  0.781640        0
# 7  0.053390  8.966770        0
# 8 -0.827918  6.742253        0
# 9  3.291716  1.296751        0

# %% [markdown]
# 65

# %%
from sklearn.cluster import DBSCAN

df = pd.read_csv("clusters.csv")

dbscan = DBSCAN(eps=0.6, min_samples=7)
dbscan.fit(df)

df["cluster"]=dbscan.labels_
df.head(10)
# Out:
#          x1        x2  cluster
# 0 -6.730717  5.548132        0
# 1 -4.613187 -5.144937        1
# 2 -4.833709 -5.412881        1
# 3  3.160670  0.558723        2
# 4  3.400393 -0.225236        2
# 5 -5.435286 -5.181777        1
# 6  4.168140  2.311239        2
# 7 -4.404109 -5.088302        1
# 8 -5.235005 -3.867119        1
# 9  5.159714  0.598213        2

# %% [markdown]
# 66

# %%
from sklearn.cluster import DBSCAN

df = pd.read_csv("clusters.csv")

dbscan = DBSCAN(eps=0.6, min_samples=7)
dbscan.fit(df)

df["cluster"]=dbscan.labels_
df["cluster"].value_counts()
# Out:
# cluster
#  0    449
#  1    232
#  2    231
# -1     88
# Name: count, dtype: int64

# %% [markdown]
# 67

# %%
from sklearn.preprocessing import StandardScaler

np.set_printoptions(suppress=True)

df = pd.read_csv("/content/pca.csv")

y = df["class"]
X= df.drop(columns="class")

std_scaler = StandardScaler()
X_std = std_scaler.fit_transform(X)
X_std
# Out:
# array([[-0.90068117, -1.34022653, -1.3154443 ],
#        [-1.14301691, -1.34022653, -1.3154443 ],
#        [-1.38535265, -1.39706395, -1.3154443 ],
#        [-1.50652052, -1.2833891 , -1.3154443 ],
#        [-1.02184904, -1.34022653, -1.3154443 ],
#        [-0.53717756, -1.16971425, -1.05217993],
#        [-1.50652052, -1.34022653, -1.18381211],
#        [-1.02184904, -1.2833891 , -1.3154443 ],
#        [-1.74885626, -1.34022653, -1.3154443 ],
#        [-1.14301691, -1.2833891 , -1.44707648],
#        [-0.53717756, -1.2833891 , -1.3154443 ],
#        [-1.26418478, -1.22655167, -1.3154443 ],
#        [-1.26418478, -1.34022653, -1.44707648],
#        [-1.87002413, -1.51073881, -1.44707648],
#        [-0.05250608, -1.45390138, -1.3154443 ],
#        [-0.17367395, -1.2833891 , -1.05217993],
#        [-0.53717756, -1.39706395, -1.05217993],
#        [-0.90068117, -1.34022653, -1.18381211],
#        [-0.17367395, -1.16971425, -1.18381211],
#        [-0.90068117, -1.2833891 , -1.18381211],
# ...

# %% [markdown]
# 69

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler


np.set_printoptions(precision=8, suppress=True, edgeitems=5, linewidth=200)
np.random.seed(42)
df = pd.read_csv('/content/pca.csv')

X = df.copy()
y = X.pop('class')

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

eig_vals, eig_vecs = np.linalg.eig(np.cov(X_std, rowvar=False))
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:, i]) for i in range(len(eig_vals))]
eig_pairs.sort(reverse=True)

W = np.hstack((eig_pairs[0][1].reshape(3, 1), eig_pairs[1][1].reshape(3, 1)))
X_pca = X_std.dot(W)

df_pca = pd.DataFrame(X_pca, columns=["pca_1", "pca_2"])
df_pca["class"] = y
df_pca.head(10)
# Out:
#       pca_1     pca_2  class
# 0 -2.060360  0.298674    0.0
# 1 -2.195981  0.101727    0.0
# 2 -2.365221 -0.080749    0.0
# 3 -2.365794 -0.208165    0.0
# 4 -2.128171  0.200201    0.0
# 5 -1.603256  0.412703    0.0
# 6 -2.323005 -0.262683    0.0
# 7 -2.094552  0.185730    0.0
# 8 -2.535034 -0.390641    0.0
# 9 -2.238771  0.156245    0.0

# %% [markdown]
# 70

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


np.set_printoptions(precision=8, suppress=True, edgeitems=5, linewidth=200)
np.random.seed(42)
df = pd.read_csv('/content/pca.csv')

X = df.copy()
y = X.pop('class')

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

pca = PCA(n_components=2)
df_pca = pd.DataFrame(pca.fit_transform(X_std), columns=["pca_1", "pca_2"])

df_pca["class"] = y
df_pca.head(10)
# Out:
#       pca_1     pca_2  class
# 0 -2.060360 -0.298674    0.0
# 1 -2.195981 -0.101727    0.0
# 2 -2.365221  0.080749    0.0
# 3 -2.365794  0.208165    0.0
# 4 -2.128171 -0.200201    0.0
# 5 -1.603256 -0.412703    0.0
# 6 -2.323005  0.262683    0.0
# 7 -2.094552 -0.185730    0.0
# 8 -2.535034  0.390641    0.0
# 9 -2.238771 -0.156245    0.0
